# %%
#importing some important modules for data manipulation 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#importing datasets through pandas and ploting a scatter 
X = pd.read_excel('./DataSets/slr10.xls')['X'];
Y = pd.read_excel('./DataSets/slr10.xls')['Y'];
plt.scatter(X,Y)
plt.show();
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
# *** No CODEPAGE record, no encoding_override: will use 'ascii'

# %%
#calculating the theta based on above data set
xTrans = X.transpose()
xTrax = np.dot(xTrans,X)
xTray = np.dot(xTrans,Y)
xTrax_inv = np.power(xTrax,-1)
theta = np.dot(xTrax_inv,xTray)
theta
# Out:
# 1.4458252224694108

# %%
#plotting the scatter based on predictions
plt.scatter(X, Y)
plt.plot(X, X * theta)
plt.show()

# %%
#predicting the accuracy of our gradient 
y_predict = np.dot(X.iloc[47],theta)
accuracy = np.divide(y_predict,Y.iloc[47])
accuracy
# Out:
# 0.95424464682981114

# %%
#reading the data for second prediction and plotting it 
X = pd.read_excel('./DataSets/slr05.xls')['X'];
Y = pd.read_excel('./DataSets/slr05.xls')['Y'];
plt.scatter(X,Y)
plt.show()
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
# *** No CODEPAGE record, no encoding_override: will use 'ascii'

# %%
#calculating theta for the data set slr05
xTrans = X.transpose()
xTrax  = np.dot(xTrans,X)
xTray  = np.dot(xTrans,Y)
xTrax_inv = np.power(xTrax,-1)
theta = np.dot(xTrax_inv,xTray)
theta
# Out:
# 2.1682978584887236

# %%
#plotting the graph according to dataset slr05
plt.scatter(X,Y)
plt.plot(X,np.dot(X,theta),"r")
plt.show()

# %%
#checking accuracy of prediction of dataset slr05
y_predict = np.dot(X.iloc[35],theta)
accuracy = np.divide(y_predict,Y.iloc[35])
accuracy
# Out:
# 0.72064017061536989
